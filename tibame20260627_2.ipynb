# %% [markdown]
# <a href="https://colab.research.google.com/github/Elwing-Chou/tibame20260618/blob/main/tibame20260627_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
for i in range(2):
    for j in range(3):
        print(j+1)
    print(i, "GO!")
# Out:
# 1
# 2
# 3
# 0 GO!
# 1
# 2
# 3
# 1 GO!

# %%
def func():
    for j in range(3):
        print(j+1)

for i in range(2):
    func()
    print("GO!")

# %%
# oxoxo
# xoxox
# oxoxo
symbols = ["o", "x", "!"]

for i in range(6):
    line = ""
    for j in range(9):
        pos = (i + j) % len(symbols)
        line = line + symbols[pos]
    print(line)
# Out:
# ox!ox!ox!
# x!ox!ox!o
# !ox!ox!ox
# ox!ox!ox!
# x!ox!ox!o
# !ox!ox!ox

# %%
l = [20, [9, 8, [0, 1, 2]], 40]
l[1][0]
l[1][2][0]
# Out:
# 0

# %%
l = [
    [1, 2, 3],
    [4, 5, 6],
    [7, 8, 9]
]
l[2][0]
# Out:
# 7
