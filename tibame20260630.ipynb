# %% [markdown]
# <a href="https://colab.research.google.com/github/Elwing-Chou/tibame20260618/blob/main/tibame20260630.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 群集型態
#
# 1. list: 清單(同類型東西的組合) [20, 30, 40] key=0 1 2 3 有序
#
# 2. dict: 字典(拿來聚集成一個複雜東西) {"姓名":"Elwing", "身高":175} key=自訂(數字/字串) 無序
#
# 3. set: 不重複的集合(使用上比較接近list) {20, 30, 10} key你無法決定 無序
#
# 4. tuple:

# %%
s = {20, 30, 10, 30}
print(s)
# Out:
# {10, 20, 30}
