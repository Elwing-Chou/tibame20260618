# %% [markdown]
# <a href="https://colab.research.google.com/github/Elwing-Chou/tibame20260618/blob/main/tibame20260618.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. markdown語法
#
# 2. colab: 線上版的(jupyter notebook: python一個工具, 讓你可以分段檢視)
#
# 3. Latex數學語法: a. ()->{} b. 特殊符號 \
# $ 標準差(\sigma) = \sqrt { \frac{1}{n} \sum_{i=n} (x_i - \mu)^2} $

# %%
a = 3
print(a)
# Out:
# 3

# %% [markdown]
# 1. 給你一個日期(20241001) 往後數 n=10 個完全平方日
#
# 2. 如果你用紙筆數, 你會怎麼數
#
# 3. 想法1(一天一天數): 20241002 開根號-> 不是整數 20241003 開根號 ........
#
# 4. 想法2(一個整數一個整數): 4499 x 4499 = 20241001 4500 x 4500 = 20250000(X)
#
# 5. 哪個想法比較好?(e.g. 下一個是20720704=4552x4552)
#
# 6. 想法1. 48年那麼多個=(48*365=17520個)
#
# 7. 想法2. 4552-4499=53個
#
# 8. 想法2(good) 跑的速度 百倍於 想法1
#
# 9. 想法2: 迴圈(4499->4500->4501) 對每一個數字 ** 2, 確定是否是一個日期(年: >= 1, 月: 12~1 日: a. 每月日期不一樣 b. 閏年2/29)

# %%
bmi = 15
if bmi > 25:
    print("過重")
elif bmi > 18:
    print("正常")
else:
    print("過輕")
# Out:
# 過輕

# %% [markdown]
# ![閏年演算法 (1).png](data:image/png;base64,...)

# %%
# 2000(o) 1800(x) 888(o) 777(x)
year = 2000
if year % 4 == 0:
    if year % 100 == 0:
        if year % 400 == 0:
            print("O")
        else:
            print("X")
    else:
        print("O")
else:
    print("X")
# Out:
# X
