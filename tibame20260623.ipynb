# %% [markdown]
# <a href="https://colab.research.google.com/github/Elwing-Chou/tibame20260618/blob/main/tibame20260623.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def is_leap_year(year):
    if year % 400 == 0:
        return True
    elif year % 100 == 0:
        return False
    elif year % 4 == 0:
        return True
    else:
        return False

print(is_leap_year(2000))
print(is_leap_year(1800))
# Out:
# True
# False

# %% [markdown]
# 1. 定義功能(函式): 參數和回傳值
#
# 2. TAB/Shift+TAB

# %%
def add(n1, n2):
    n3 = n1 + n2
    return n3

print(add(3, 5))
print(add(4, 6))
# Out:
# 8
# 10

# %%
def is_date_valid(d):
    # 把年月日分開
    day = d % 100
    remain = d // 100
    month = remain % 100
    year = remain // 100
    # print(year, month, day)

    if year >= 1:
        if 1 <= month <= 12:
            max_days_per_month = [31, 28, 31, 30, 31, 30, 31, 31, 30, 31, 30, 31]
            max_days = max_days_per_month[month-1]
            # if month == 2 and is_leap_year(year) == True
            if month == 2 and is_leap_year(year):
                max_days = max_days + 1
            if 1 <= day <= max_days:
                return True
            else:
                # day invalid
                return False
        else:
            # month invalid
            return False
    else:
        # year invalid
        return False

print(is_date_valid(20000229))
print(is_date_valid(20230229))
# Out:
# True
# False

# %% [markdown]
# 1. 走過一群東西(list/str): for 名字 in 群
# 2. 固定做幾次的: for i in range(次) i=0 1 2 3...次-1
# 3. 不固定次: while True+break

# %%
def strategy_2(start=4499, max_count=10):
    result = []
    count = 0
    while True:
        d = start * start
        # if is_date_valid(d) == True
        if is_date_valid(d):
            result.append(d)
            count = count + 1
        if count == max_count:
            break
        start = start + 1
    return result

print(strategy_2())
print(strategy_2(max_count=5))
# Out:
# [20241001, 20720704, 20930625, 21150801, 21390625, 21520321, 21641104, 21650409, 21790224, 21921124]
# [20241001, 20720704, 20930625, 21150801, 21390625]
